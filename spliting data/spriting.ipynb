# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('dataset.csv')
print(df.columns)
# Out:
# Index(['Mileage (km)', 'Age (years)', 'Sell_Price ($)'], dtype='object')

# %%
plt.scatter(df['Mileage (km)'], df['Sell_Price ($)'])

# %%
x = df[['Mileage (km)', 'Age (years)']]
y = df['Sell_Price ($)']
# Out:
#    Mileage (km)  Age (years)
# 0            50            2
# 1           120            5
# 2            80            3
# 3           200            8
# 4            30            1
# 5           150            6
# 6            90            4
# 7            60            2
# 8           180            7
# 9            40            1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(x_train)
# Out:
#    Mileage (km)  Age (years)
# 0            50            2
# 9            40            1
# 2            80            3
# 7            60            2
# 8           180            7
# 3           200            8
# 5           150            6
# 4            30            1

# %%
len(x_test)
# Out:
# 2

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ -71., -545.])

# %%
model.intercept_
# Out:
# np.float64(25305.0)

# %%
model.predict(x_test)
# Out:
# array([14060., 16735.])

# %%
y_test
# Out:
# 1    12000
# 6    15000
# Name: Sell_Price ($), dtype: int64

# %%
model.score(x_test, y_test)
# Out:
# -0.6119611111111156
