# %%
# L1 and L2 regularization it solve the overfitting and underfitting problem
# how to reduce overfitting: try to make eq2 and eq3 almost close to zero
# for L1 we use absolute value while L2 we use square

# %%
import seaborn as sns
import pandas as pd
