# %%
# binary classification: is process that logicstic uses to classify two solution. true/false/ yes or no
# multiclass classification: process that logistic use to pick one or choose one in multiplce selections

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Age  Have_Insurance
# 0   18               0
# 1   20               0
# 2   22               0
# 3   24               0
# 4   26               0

# %%
plt.scatter(df['Age'], df['Have_Insurance'], marker='+', color='red')
plt.show
# you can predict value by using linear regression line
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Age']], df.Have_Insurance, test_size=0.1)

# %%
X_test
# Out:
#     Age
# 13   44
# 10   38

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1])

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
# predict with probability
model.predict_proba(X_test)
# Out:
# array([[3.70230706e-06, 9.99996298e-01],
#        [1.18924066e-03, 9.98810759e-01]])

# %%
model.predict([[100]])
# Out:
# /home/etiene-niyomugabo123/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
